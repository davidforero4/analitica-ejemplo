# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/ventas.csv")
df.head()
# Out:
#    dia  ventas
# 0    1     100
# 1    2     120
# 2    3      90
# 3    4     150
# 4    5     130

# %%
df.describe()
# Out:
#             dia      ventas
# count  7.000000    7.000000
# mean   4.000000  131.428571
# std    2.160247   30.237158
# min    1.000000   90.000000
# 25%    2.500000  110.000000
# 50%    4.000000  130.000000
# 75%    5.500000  155.000000
# max    7.000000  170.000000

# %%
plt.plot(df["dia"], df["ventas"])
plt.xlabel("Día")
plt.ylabel("Ventas")
plt.title("Ventas por día")
plt.show()

# %%
import sys
sys.path.append("../src")

from load_data import cargar_ventas
from estadisticas import calcular_estadisticas
from graficos import grafico_linea

# %%
df = cargar_ventas()
df
# Out:
#    dia  ventas
# 0    1     100
# 1    2     120
# 2    3      90
# 3    4     150
# 4    5     130
# 5    6     170
# 6    7     160

# %%
calcular_estadisticas(df)
# Out:
#             dia      ventas
# count  7.000000    7.000000
# mean   4.000000  131.428571
# std    2.160247   30.237158
# min    1.000000   90.000000
# 25%    2.500000  110.000000
# 50%    4.000000  130.000000
# 75%    5.500000  155.000000
# max    7.000000  170.000000

# %%
grafico_linea(df)

# %%
grafico_linea(df, save=True)
# Out:
# Gráfico guardado en: ..\reports\figures\ventas.png

# %%
import sys
sys.path.append("../src")

from load_data import cargar_ventas
from modelo import predecir_venta

df = cargar_ventas("../data/ventas.csv")
predecir_venta(df, 8)
# Out:
# d:\Documents\Analitica\analitica-ejemplo\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 177.1428571428571

# %%
import sys
sys.path.append("../src")

from database import inicializar_bd, obtener_ventas_semana

# %%
inicializar_bd()
df_sem1 = obtener_ventas_semana(1)
df_sem1
# Out:
#    dia  ventas
# 0    1   100.0
# 1    2   120.0
# 2    3    90.0
# 3    4   150.0
# 4    5   130.0
# 5    6   170.0
# 6    7   160.0

# %%
from database import BASE_DIR, DB_PATH
BASE_DIR, DB_PATH
# Out:
# (WindowsPath('D:/Documents/Analitica/analitica-ejemplo'),
#  WindowsPath('D:/Documents/Analitica/analitica-ejemplo/data/ventas.db'))
