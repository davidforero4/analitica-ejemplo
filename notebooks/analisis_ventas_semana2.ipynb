# %%
import sys
sys.path.append("../src")

from load_data import cargar_ventas
from estadisticas import calcular_estadisticas
from graficos import grafico_linea

# %%
df2 = cargar_ventas("../data/ventas_semana2.csv")
df2
# Out:
#    dia  ventas
# 0    1     180
# 1    2     160
# 2    3     200
# 3    4     190
# 4    5     210
# 5    6     195
# 6    7     220

# %%
calcular_estadisticas(df2)
# Out:
#             dia      ventas
# count  7.000000    7.000000
# mean   4.000000  193.571429
# std    2.160247   19.730325
# min    1.000000  160.000000
# 25%    2.500000  185.000000
# 50%    4.000000  195.000000
# 75%    5.500000  205.000000
# max    7.000000  220.000000

# %%
grafico_linea(df2, save=True, path="../reports/figures/ventas_semana2.png")
# Out:
# Gráfico guardado en: ..\reports\figures\ventas_semana2.png
